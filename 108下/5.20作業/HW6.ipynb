# %% [markdown]
# # 選歌

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from IPython.display import display, HTML, Markdown, YouTubeVideo, Image

# %%
v = [0,1,2,3,4,5]
v[0] = YouTubeVideo('Dtu5yGDttCw')
v[1] = YouTubeVideo('-jbF5IQqj1U')
v[2] = YouTubeVideo('VznBK_Yv6YI')
v[3] = YouTubeVideo('3fjdED2RqKQ')
v[4] = YouTubeVideo('mrP_cpcuNEc')
v[5] = YouTubeVideo('TgOu00Mf3kI')

# %%
print('0:Punch (펀치) - Done For Me')
print('1:준 & 찬 of A.C.E(에이스) - Where You Are')
print('2:UNB - 감각 (Feeling)')
print('3:Ailee (에일리) –첫눈처럼 너에게 가겠다 (I will go to you like the first snow)')
print('4:Apink(에이핑크) _ Dumhdurum(덤더럼)')
print('5:IU(아이유) _ eight(에잇) (Prod.&Feat. SUGA of BTS)')
k = int(input('請輸入你要的歌曲代號:'))
display(v[k])
# Out:
# 0:Punch (펀치) - Done For Me
# 1:준 & 찬 of A.C.E(에이스) - Where You Are
# 2:UNB - 감각 (Feeling)
# 3:Ailee (에일리) –첫눈처럼 너에게 가겠다 (I will go to you like the first snow)
# 4:Apink(에이핑크) _ Dumhdurum(덤더럼)
# 5:IU(아이유) _ eight(에잇) (Prod.&Feat. SUGA of BTS)
# 請輸入你要的歌曲代號:5

# %% [markdown]
# # Markdown

# %% [markdown]
# ### 超連結
# [Craig David - Insomnia](https://www.youtube.com/watch?v=tnrTN7s-p6Y)
