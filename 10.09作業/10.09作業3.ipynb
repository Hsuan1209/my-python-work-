# %% [markdown]
# # 作業三 選歌小幫手

# %%
from IPython.display import display, HTML, Markdown, Image, YouTubeVideo
from numpy.random import randint

# %%
a = YouTubeVideo('kqckfuUnC1U')
b = YouTubeVideo('6RLLOEzdxsM')
c = YouTubeVideo('A_1t2Dkd2Io')
d = YouTubeVideo('3qTAxAEhH08')
e = YouTubeVideo('41txh0FXTrk')

# %%
v = [a,b,c,d,e]

# %%
display(v[randint(0,5)])
