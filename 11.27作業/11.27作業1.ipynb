# %% [markdown]
# # 小型點歌機

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from IPython.display import display, HTML, Markdown, Image, YouTubeVideo

# %%
v = [0,1,2,3,4,5]
v[0] = YouTubeVideo('tnrTN7s-p6Y')
v[1] = YouTubeVideo('7JJfJgyHYwU')
v[2] = YouTubeVideo('23k5062WrDw')
v[3] = YouTubeVideo('UYwF-jdcVjY')
v[4] = YouTubeVideo('n1a7o44WxNo')
v[5] = YouTubeVideo('8WYHDfJDPDc')

# %%
print('0:Craig David - Insomnia')
print('1:Rixton - Me and My Broken Heart')
print('2:Shawn Mendes, Camila Cabello - Señorita')
print('3:Post Malone - Better Now')
print('4:Zedd - Beautiful Now ft. Jon Bellion')
print('5:Nelly - Dilemma ft. Kelly Rowland')
k = int(input('請輸入你要的歌曲代號:'))
display(v[k])
# Out:
# 0:Craig David - Insomnia
# 1:Rixton - Me and My Broken Heart
# 2:Shawn Mendes, Camila Cabello - Señorita
# 3:Post Malone - Better Now
# 4:Zedd - Beautiful Now ft. Jon Bellion
# 5:Nelly - Dilemma ft. Kelly Rowland
# 請輸入你要的歌曲代號:0
