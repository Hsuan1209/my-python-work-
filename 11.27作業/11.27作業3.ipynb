# %% [markdown]
# # 一次點多首歌

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from IPython.display import display, HTML, Markdown, Image, YouTubeVideo

# %%
v = [0,1,2,3,4,5]
v[0] = YouTubeVideo('Kd3j29vXr9s')
v[1] = YouTubeVideo('ouR4nn1G9r4')
v[2] = YouTubeVideo('vuZcDpyi1oU')
v[3] = YouTubeVideo('qFcF2o6Sm3Y')
v[4] = YouTubeVideo('FWTfKpZ0VWU')
v[5] = YouTubeVideo('G6tW8eKUR1E')

# %%
print('0:S.E.S - Just in Love')
print('1:HIGH4, IU _ Not Spring, Love, or Cherry Blossoms')
print('2:APRIL - Feeling')
print('3:Bolbbalgan4_ You(=I)')
print('4:Davichi - 8282')
print('5:Monday Kiz, Punch - Another Day')
a = int(input('你要幾首歌?:'))
for i in range (a):
    k = int(input('請輸入你要的歌曲代號:'))
    display(v[k])
# Out:
# 0:S.E.S - Just in Love
# 1:HIGH4, IU _ Not Spring, Love, or Cherry Blossoms
# 2:APRIL - Feeling
# 3:Bolbbalgan4_ You(=I)
# 4:Davichi - 8282
# 5:Monday Kiz, Punch - Another Day
# 你要幾首歌?:2
# 請輸入你要的歌曲代號:0
# 請輸入你要的歌曲代號:2
