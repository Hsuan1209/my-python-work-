# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import json

# %% [markdown]
# # 讀入資料

# %%
df = pd.read_json('https://cloud.culture.tw/frontsite/trans/SearchShowAction.do?method=doFindTypeJ&category=8')

# %%
df.head()
# Out:
#                         UID  category comment  \
# 0  5c27c59bd083a32edcb4d5f5         8
# 1  5c3f803fd083a35404c3cd3a         8
# 2  5c46174dd083a35404c3ce8b         8
# 3  5c46174dd083a35404c3ce8c         8
# 4  5c46174fd083a35404c3ce97         8
#
#                                descriptionFilterHtml           discountInfo  \
# 0  播放影片：\r\n09:20 花帔阿獺\r\n10:20 瑠公引水的故事\r\n11:20 ...  滿65歲以上，平日憑證免費，假日憑證半價。
# 1  上午場10:00-11:30／體驗藍洞\r\n 澎湖南方四島國家公園西吉嶼的藍洞是天然的玄武...         滿65歲以上假日憑證25元。
# 2                                            西屯假日電影院
# 3                                            西屯假日電影院
# 4                                     溪西假日放電影，歡迎親子觀賞
#
#   editModifyDate     endDate  hitRate imageUrl            masterUnit  ...  \
# 0                 2019/12/31        0           [國立自然科學博物館車籠埔斷層保存園區]  ...
# 1                 2019/12/31        0                    [國立自然科學博物館]  ...
# 2                 2019/11/24        0                  [臺中市立圖書館西屯分館]  ...
# ...

# %% [markdown]
# # 刪減資料

# %%
df.drop("subUnit",axis = 1,inplace = True)

# %%
df.head()
# Out:
#                         UID  category comment  \
# 0  5c27c59bd083a32edcb4d5f5         8
# 1  5c3f803fd083a35404c3cd3a         8
# 2  5c46174dd083a35404c3ce8b         8
# 3  5c46174dd083a35404c3ce8c         8
# 4  5c46174fd083a35404c3ce97         8
#
#                                descriptionFilterHtml           discountInfo  \
# 0  播放影片：\r\n09:20 花帔阿獺\r\n10:20 瑠公引水的故事\r\n11:20 ...  滿65歲以上，平日憑證免費，假日憑證半價。
# 1  上午場10:00-11:30／體驗藍洞\r\n 澎湖南方四島國家公園西吉嶼的藍洞是天然的玄武...         滿65歲以上假日憑證25元。
# 2                                            西屯假日電影院
# 3                                            西屯假日電影院
# 4                                     溪西假日放電影，歡迎親子觀賞
#
#   editModifyDate     endDate  hitRate imageUrl            masterUnit  \
# 0                 2019/12/31        0           [國立自然科學博物館車籠埔斷層保存園區]
# 1                 2019/12/31        0                    [國立自然科學博物館]
# 2                 2019/11/24        0                  [臺中市立圖書館西屯分館]
# ...

# %%
df.drop("supportUnit",axis = 1,inplace = True)

# %%
df.head()
# Out:
#                         UID  category comment  \
# 0  5c27c59bd083a32edcb4d5f5         8
# 1  5c3f803fd083a35404c3cd3a         8
# 2  5c46174dd083a35404c3ce8b         8
# 3  5c46174dd083a35404c3ce8c         8
# 4  5c46174fd083a35404c3ce97         8
#
#                                descriptionFilterHtml           discountInfo  \
# 0  播放影片：\r\n09:20 花帔阿獺\r\n10:20 瑠公引水的故事\r\n11:20 ...  滿65歲以上，平日憑證免費，假日憑證半價。
# 1  上午場10:00-11:30／體驗藍洞\r\n 澎湖南方四島國家公園西吉嶼的藍洞是天然的玄武...         滿65歲以上假日憑證25元。
# 2                                            西屯假日電影院
# 3                                            西屯假日電影院
# 4                                     溪西假日放電影，歡迎親子觀賞
#
#   editModifyDate     endDate  hitRate imageUrl            masterUnit  \
# 0                 2019/12/31        0           [國立自然科學博物館車籠埔斷層保存園區]
# 1                 2019/12/31        0                    [國立自然科學博物館]
# 2                 2019/11/24        0                  [臺中市立圖書館西屯分館]
# ...

# %% [markdown]
# # 分析最早開始的活動和它的結束日期

# %%
df_date = df[["masterUnit","descriptionFilterHtml","startDate","endDate"]]

# %%
df_date = df_date.sort_values("startDate",ascending=True,inplace=False)

# %%
df_date.head()
# Out:
#               masterUnit                              descriptionFilterHtml  \
# 0   [國立自然科學博物館車籠埔斷層保存園區]  播放影片：\r\n09:20 花帔阿獺\r\n10:20 瑠公引水的故事\r\n11:20 ...
# 1            [國立自然科學博物館]  上午場10:00-11:30／體驗藍洞\r\n 澎湖南方四島國家公園西吉嶼的藍洞是天然的玄武...
# 66            [文化部文化資產局]  「澎湖水下文化資產-黑水溝傳奇」多媒體展，分為「勇渡險惡黑水溝」、「水下考古知識」、「水凝時...
# 6             [新北市政府文化局]                            藉由影片介紹鶯歌陶博館的建築特色、歷史與使命。
# 30           [新北市立圖書館總館]  匯集來自世界各地優質雙語兒童繪本，將繪本結合多媒體效果、重新製作成精緻的動畫書，讓孩子除了眼...
#
#      startDate     endDate
# 0   2019/01/01  2019/12/31
# 1   2019/01/01  2019/12/31
# 66  2019/01/01  2019/11/29
# 6   2019/01/01  2019/12/31
# 30  2019/04/03  2019/11/27
